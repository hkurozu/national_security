# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/自然災害被害状況.csv')

print(df)

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

plt.title('Damage from natural disasters, Japan', fontsize=10)
ax1.bar(df['Year'], df['り災者数'], width=.8, color='steelblue', label='Number of people affected')
ax2.plot(df['Year'], df['被害総額（100万円）'], color='darkorange', label='Total amount of damage (million yen)')

plt.xticks(df['Year'])

ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

ax1.set_ylim(0, 177000)
ax2.set_ylim(0, 6800000)

ax1.set_xlabel('year')
ax1.set_ylabel('Number of people affected')
ax2.set_ylabel('Total amount of damage (million yen)')


handler1, label1 = ax1.get_legend_handles_labels()
handler2, label2 = ax2.get_legend_handles_labels()
ax1.legend(handler1 + handler2, label1 + label2, labelcolor="k",facecolor='w', edgecolor='w', framealpha=0.8, ncol=2, loc='upper center', borderaxespad=0., fontsize=8)
# Out:
#    年次（平成）  Year   り災世帯数    り災者数  被害総額（100万円）      死者  行方不明者     重傷     軽傷  \
# 0      17  2005   14467   30621       481678     258      2    996  2,514
# 1      18  2006    5774   13764       534868     164     13    579  1,254
# 2      19  2007   12223   33221       393854      37      4    553  2,563
# 3      20  2008    4984   12090       261276      88     13    373  1,040
# 4      21  2009    6259   15258       246241     113      2    284    807
# 5      22  2010    2828    6200       206729      84      5    281    616
# 6      23  2011  243898  142417      6418728  17,051  2,942  1,574  7,127
# 7      24  2012   17048   27210       397221     189      3    996  1,908
# 8      25  2013    8392   17691       365918     166      7    644  1,337
#
#         全壊  ...   流失埋没      冠水 流失埋没.1   冠水.1 学校（箇所） 橋りょう（箇所）  河川（箇所） 崖くずれ（箇所）  \
# 0    1,391  ...  3,344   6,509    661  1,099    ...      203   9,260      983
# ...
