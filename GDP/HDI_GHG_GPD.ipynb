# %%
import pandas as pd
import matplotlib.pyplot as plt

gdp_per_capita = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/GDP/imf-dm-export-20231118 2/NGDPDPC-1-表1.csv')

plt.title('Per capita GDP', fontsize=10)
plt.plot(gdp_per_capita['year'], gdp_per_capita['Advanced'], color='k', label='advanced')
plt.plot(gdp_per_capita['year'], gdp_per_capita['World'], color='k', linestyle='--', label='world')
plt.plot(gdp_per_capita['year'], gdp_per_capita['Developing'], color='k', linestyle=':',label='developing')

plt.xticks(gdp_per_capita['year'][::4], fontsize=10)
plt.yticks(plt.yticks()[0], ["{:,}".format(int(i)) for i in plt.yticks()[0]])
plt.ylim([0,60000])
plt.xlabel('year', fontsize=10)
plt.ylabel('US$', fontsize=10)
plt.legend(fontsize=8)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 gdp_per_capita = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/GDP/imf-dm-export-20231118 2/NGDPDPC-1-表1.csv')
#       6 plt.title('Per capita GDP', fontsize=10)
#       7 plt.plot(gdp_per_capita['year'], gdp_per_capita['Advanced'], color='k', label='advanced')
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

mf = pd.read_csv('/Users/kurozuhajime/Desktop/Pythonコード・データ/GDP/GDPdata/mfa_totals_ratios_export/MF-表1.csv')
df = pd.read_csv('/Users/kurozuhajime/Desktop/Pythonコード・データ/GDP/GDPdata/mfa_totals_ratios_export/シート1-mfa_totals_ratios_export.csv')

country = ['Canada', 'Costa Rica', 'Mexico', 'United States of America']

c1 = ['Country', 'Flow code']

c2 = 'MF/cap'

yr = range(1970, 2024+1)

"""
plt.figure(facecolor='k')
ax = plt.axes()
ax.set_facecolor('k')
"""

#plt.title('Material Footprint', color='w', fontsize=10)
plt.title('Material Footprint', color='k', fontsize=10)


for i, ctry in enumerate(country):
    data = df[(df[c1[0]] == ctry) & (df[c1[1]] == c2)]
    #print(data)
    plt.plot(yr, data.iloc[0, 4:], label=ctry)

"""
for i in range(len(mf)):
    data = mf.iloc[i,1:]
    #print(data)
    area = mf.iloc[i,0]
    #print(area)
    #print(data.iloc[1])
    
    plt.plot(yr, data/1000000000, label=area)

"""    
"""
ax.spines['left'].set_color('w')
ax.spines['bottom'].set_color('w')
# ラベルの色
ax.xaxis.label.set_color('w')
ax.yaxis.label.set_color('w')
# 目盛りの色
ax.tick_params(axis='x', colors='w')
ax.tick_params(axis='y', colors='w')
"""

plt.ylim(0, 56)
plt.xticks(yr[::3], fontsize=10, rotation=90)
plt.xlabel('year',fontsize=10)
plt.ylabel('material footprint per capita (tone)',fontsize=10)

#plt.legend(labelcolor="w",facecolor='k', edgecolor='k', framealpha=0.8, ncol=4, loc='upper center', fontsize=8)
plt.legend(labelcolor="k",facecolor='w', edgecolor='w', framealpha=0.8, ncol=4, loc='upper center', fontsize=8)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

hdi = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/Degrowth:Greengrowth/human-development-index.csv')
ghg = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/Goal13気候変動/World_気象データ/total-ghg-emissions/per-capita-ghg-emissions.csv')
gdp = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/GDP/gdp-per-capita-worldbank.csv')
ppl = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/Degrowth:Greengrowth/population.csv')

clm = ('Entity', 'Code', 'Year', 'Human Development Index', 'Per-capita greenhouse gas emissions in CO₂ equivalents')
clm = ['Entity', 'Code', 'Year', 'HDI', 'GHG', 'GDP', 'PPL']


#print(ghg.tail(20))
#print(hdi[10:34])

ctry_code = [['DNK'], ['USA','CAN'],['FRA', 'GBR'], ['QAT', 'ARE'], ['CRI','BRA','CHL'], ['AUS', 'NZL'], ['ETH','TZA','TCD'],\
              ['MYS','JPN'],['IND', 'LKA' ], ['UZB','AFG']]
clr_code = ['PuBu', 'Blue','PuRd', 'Purp', 'Green', 'Red', 'Org', 'GnBu','Gry','RdPu']

ctry_code_2 = ['DNK', 'USA','CAN','FRA', 'GBR', 'QAT', 'ARE', 'CRI','BRA','CHL', 'AUS', 'NZL', 'ETH','TZA','TCD','MYS','JPN','IND', 'LKA' , 'UZB','AFG']


#df1 = pd.merge(hdi, ghg)
#df = pd.merge(df1, ppl)

#print(df)

#print(df[df['Code'] == 'ETH']['Year'])

#-------------------------------------------
df1 = pd.merge(hdi, ghg)
df2 = pd.merge(df1, gdp)
df = pd.merge(df2, ppl)


df.columns = clm
#print(df)
style = dict(size=5, color='k')
x_base = np.linspace(0.5, 1, 10)
#print(x_base)
y_base = np.full(10, 5)
y_zero = np.zeros(10)
plt.title('Per-capita GHG emissions vs. Human Development Index (1990-2021)', fontsize=10)
plt.fill_between(x_base, y_base, y_zero, alpha = 0.4, color='orange')
plt.text(0.84, 1, f'Sustainable Development\nCorridor', **style)
plt.xlim(0, 1)
plt.ylim(0, 80)
plt.xlabel('Human Development Index', fontsize=10)
plt.ylabel('Per-capita GHG emissions (t CO2eq)', fontsize=10)
#plt.show()

style = dict(size=6, color='k')
for i, catgry in enumerate(ctry_code):
    #print(catgry)
    for ctry in catgry:
        #ax = plt.axes(projection='3d')
        #z = df[df['Code'] == 'USA']['Year']
        #print(ctry)
        Yr = df[df['Code'] == ctry]['Year']
        #print(Yr)
        ST_yr = Yr.iloc[0]
        #print(ST_yr)
        l = len(Yr)
        #print(l)
        ED_yr = Yr.iloc[l-1]
        #print(ED_yr)
        #Dat = df[(df['Year']==2021) & (df['Code'] == ctry) & (df['HDI'] >= 0.5) & (df['GHG'] <= 5.0 )]
        #Dat.colums = None
        #print(Dat)


        x = df[df['Code'] == ctry]['HDI']
        y = df[df['Code'] == ctry]['GHG']
        z = df[df['Code'] == ctry]['GDP']
        p = df[df['Code'] == ctry]['PPL']
        pp = df[df['Code'] == 'OWID_WRL']['PPL']
        #print(pp.tail(10)) 
        s = 2
        lw = 2
        #s = df[df['Code'] == ctry]['Population (historical estimates)']
        #ax.plot3D(x, y, z)
        #ax.set_ylim3d(0, 28)

        if clr_code[i] == 'Blue':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Blues(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6, color='steelblue')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='steelblue')
            
        
        elif clr_code[i] == 'Purp':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):  
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])
                kk = k  
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Purples(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='purple')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='purple')
            
        
        elif clr_code[i] == 'Green':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])
                kk = k  
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greens(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='green')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='green')
            
        elif clr_code[i] == 'Red':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Reds(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='red')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='red')
            
        
        elif clr_code[i] == 'Org':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1): 
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Oranges(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='orange')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='orange')
            
        
        elif clr_code[i] == 'Gry':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greys(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='gray')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='gray')
            
        
        elif clr_code[i] == 'GnBu':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.GnBu(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color=cm.GnBu(28+k*6))
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color=cm.GnBu(28+k*6))
            
        
        elif clr_code[i] == 'RdPu':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.RdPu(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color=cm.RdPu(28+k*6))
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color=cm.RdPu(28+k*6))
            
        
        elif clr_code[i] == 'PuRd':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuRd(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color=cm.PuRd(28+k*6))
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color=cm.PuRd(28+k*6))
            
        
        elif clr_code[i] == 'PuBu':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuBu(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color=cm.PuBu(28+k*6))
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color=cm.PuBu(28+k*6))
                    
        #input()
        

        
        plt.text(x.iloc[kk], y.iloc[kk], f'{ctry}', **style)
        #plt.show()

x2 = []
for ctry in ctry_code_2:
    x1 = df[(df['Code'] == ctry) & (df['Year'] == 2021)].to_numpy()
    #print(x1[0])
    x2.append(x1[0])
#print(x2)
data = pd.DataFrame(x2)
data.columns = clm
print(data)

#sns.pairplot(data, hue='category', palette='Blues')
# Out:
#                   Entity Code  Year    HDI        GHG         GDP         PPL
# 0                Denmark  DNK  2021  0.948   7.609710  57962.6520     5854246
# 1          United States  USA  2021  0.921  17.583845  63669.7100   336997632
# 2                 Canada  CAN  2021  0.936  20.372282  47892.9450    38155012
# 3                 France  FRA  2021  0.903   6.055762  44993.1250    64531448
# 4         United Kingdom  GBR  2021  0.929   6.255776  44978.7150    67281040
# 5                  Qatar  QAT  2021  0.855  76.567670  92862.3500     2688239
# 6   United Arab Emirates  ARE  2021  0.911  28.138329  69733.8000     9365149
# 7             Costa Rica  CRI  2021  0.809   2.793394  21199.2810     5153959
# 8                 Brazil  BRA  2021  0.754  10.031076  14592.3530   214326224
# 9                  Chile  CHL  2021  0.855   6.361327  25449.1300    19493184
# 10             Australia  AUS  2021  0.951  23.244528  49774.3400    25921094
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

hdi = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/Degrowth:Greengrowth/human-development-index.csv')
ghg = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/Goal13気候変動/World_気象データ/total-ghg-emissions/per-capita-ghg-emissions.csv')
gdp = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/GDP/gdp-per-capita-worldbank.csv')
ppl = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/Degrowth:Greengrowth/population.csv')

clm = ('Entity', 'Code', 'Year', 'Human Development Index', 'Per-capita greenhouse gas emissions in CO₂ equivalents')
clm = ['Entity', 'Code', 'Year', 'HDI', 'GHG', 'GDP']


#print(ghg.tail(20))
#print(hdi[10:34])

ctry_code = [['DNK'], ['USA','CAN'],['FRA', 'GBR'], ['QAT', 'ARE'], ['CRI','BRA','CHL'], ['AUS', 'NZL'], ['ETH','TZA','TCD'],\
              ['MYS','JPN'],['IND', 'LKA' ], ['UZB','AFG']]
clr_code = ['PuBu', 'Blue','PuRd', 'Purp', 'Green', 'Red', 'Org', 'GnBu','Gry','RdPu']


#df1 = pd.merge(hdi, ghg)
#df = pd.merge(df1, ppl)

#print(df)

#print(df[df['Code'] == 'ETH']['Year'])

"""
#-------------------------------------------
data = ghg[ghg['Code'] == 'OWID_WRL']
#print(data)
ST_yr = data.iloc[0]['Year']
ED_yr = data.iloc[len(data['Year'])-1]['Year']

#print(ST_yr)
#print(ED_yr)

x = range(ST_yr, ED_yr+1)
y = data['Per-capita greenhouse gas emissions in CO₂ equivalents']

fig = plt.subplot()
plt.title('Per-capita greenhouse gas emissions in CO₂ equivalents, world', fontsize=10)
plt.plot(x, y)
plt.ylabel('Per-capita GHG emissions (t-co2eq)', fontsize=10)
plt.xlabel('year')
plt.xticks(x[::], rotation=90)
plt.xlim(1990, 2022)
plt.show()

#-------------------------------------------
data = hdi[hdi['Code'] == 'OWID_WRL']
#print(data)
ST_yr = data.iloc[0]['Year']
ED_yr = data.iloc[len(data['Year'])-1]['Year']

print(ST_yr)
print(ED_yr)

x = range(ST_yr, ED_yr+1)
y = data['Human Development Index']

plt.title('Human Development Index, world', fontsize=10)
plt.plot(x, y)
plt.ylabel('Human Development Index', fontsize=10)
plt.xlabel('year')
plt.xticks(x[::], rotation=90)
plt.xlim(1990, 2022)
plt.show()


"""
#-------------------------------------------
df1 = pd.merge(hdi, ghg)
df = pd.merge(df1, gdp)

df.columns = clm
style = dict(size=5, color='k')
x_base = np.linspace(0.5, 1, 10)
#print(x_base)
y_base = np.full(10, 5)
y_zero = np.zeros(10)
plt.title('Per-capita GHG emissions vs. Human Development Index (1990-2021)', fontsize=10)
plt.fill_between(x_base, y_base, y_zero, alpha = 0.4, color='orange')
plt.text(0.84, 1, f'Sustainable Development\nCorridor', **style)
plt.xlim(0, 1)
plt.ylim(0, 80)
plt.xlabel('Human Development Index', fontsize=10)
plt.ylabel('Per-capita GHG emissions (t CO2eq)', fontsize=10)
#plt.show()

style = dict(size=6, color='k')
for i, catgry in enumerate(ctry_code):
    #print(catgry)
    for ctry in catgry:
        #ax = plt.axes(projection='3d')
        #z = df[df['Code'] == 'USA']['Year']
        #print(ctry)
        Yr = df[df['Code'] == ctry]['Year']
        #print(Yr)
        ST_yr = Yr.iloc[0]
        #print(ST_yr)
        l = len(Yr)
        #print(l)
        ED_yr = Yr.iloc[l-1]
        #print(ED_yr)
        #Dat = df[(df['Year']==2021) & (df['Code'] == ctry) & (df['HDI'] >= 0.5) & (df['GHG'] <= 5.0 )]
        #Dat.colums = None
        #print(Dat)
        x = df[df['Code'] == ctry]['HDI']
        y = df[df['Code'] == ctry]['GHG']
        z = df[df['Code'] == ctry]['GDP']
        
        #s = df[df['Code'] == ctry]['Population (historical estimates)']
        #ax.plot3D(x, y, z)
        #ax.set_ylim3d(0, 28)

        if clr_code[i] == 'Blue':
            for k in range(ED_yr-ST_yr+1):
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Blues(28+k*6))
        elif clr_code[i] == 'Purp':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Purples(28+k*6))
        elif clr_code[i] == 'Green':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greens(28+k*6))
        elif clr_code[i] == 'Red':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Reds(28+k*6))
        elif clr_code[i] == 'Org':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Oranges(28+k*6))
        elif clr_code[i] == 'Gry':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greys(28+k*6))
        elif clr_code[i] == 'GnBu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.GnBu(28+k*6))
        elif clr_code[i] == 'RdPu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.RdPu(28+k*6))
        elif clr_code[i] == 'PuRd':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuRd(28+k*6))
        elif clr_code[i] == 'PuBu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuBu(28+k*6))
                
        #input()
                
        x1 = df[df['Code'] == ctry]
        y1 = df[df['Code'] == ctry]
        z1 = df[df['Code'] == ctry]
        

        print(x1)

        
        plt.text(x.iloc[k], y.iloc[k], f'{ctry}', **style)
        #plt.show()
# Out:
#        Entity Code  Year    HDI        GHG        GDP
# 1271  Denmark  DNK  1990  0.834  13.544019  39027.980
# 1272  Denmark  DNK  1991  0.838  15.547473  39469.324
# 1273  Denmark  DNK  1992  0.841  14.362214  40108.890
# 1274  Denmark  DNK  1993  0.844  14.574973  39979.758
# 1275  Denmark  DNK  1994  0.851  15.423184  41969.688
# 1276  Denmark  DNK  1995  0.854  14.743815  43015.676
# 1277  Denmark  DNK  1996  0.862  17.187155  44013.387
# 1278  Denmark  DNK  1997  0.869  15.293048  45260.137
# 1279  Denmark  DNK  1998  0.876  14.268782  46096.370
# 1280  Denmark  DNK  1999  0.886  13.691669  47298.540
# 1281  Denmark  DNK  2000  0.889  13.064765  48907.010
# 1282  Denmark  DNK  2001  0.895  13.268905  49133.223
# 1283  Denmark  DNK  2002  0.896  13.023491  49204.900
# 1284  Denmark  DNK  2003  0.901  13.995290  49262.645
# 1285  Denmark  DNK  2004  0.906  13.199531  50446.543
# 1286  Denmark  DNK  2005  0.911  12.439692  51483.273
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

gdp = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/GDP/gdp-per-capita-worldbank.csv')

df = pd.merge(gdp, hdi)
#print(df)
#df = pd.merge(df1, ppl)

#data1 = df[df['Human Development Index'] >= 0.5]
#data2 = data1[data1['Per-capita greenhouse gas emissions in CO₂ equivalents'] <= 5]
#print(data2)
#data = data2.groupby('Entity')[['Human Development Index', 'Per-capita greenhouse gas emissions in CO₂ equivalents']].mean()
#print(data)

#print(df)
#data1 = df[df['Per-capita greenhouse gas emissions in CO₂ equivalents'] > 40]
#data = data1[data1['Per-capita greenhouse gas emissions in CO₂ equivalents'] < 50]
#print(data.head(20))
#plt.plot(df['Year'], df['Per-capita greenhouse gas emissions in CO₂ equivalents'])
#plt.show()

fig = plt.subplot()
plt.title('Human Development Index vs. GDP per capita (1990-2021)', fontsize=10)
plt.xlim(0, 120000)
plt.ylim(0, 1)
plt.xlabel('Per-capita GDP ($)', fontsize=10)
plt.ylabel('Human Development Index', fontsize=10)
#plt.show()

#print(df)
style = dict(size=6, color='k')
for i, catgry in enumerate(ctry_code):
    print(catgry)
    for ctry in catgry:
        #ax = plt.axes(projection='3d')
        #z = df[df['Code'] == 'USA']['Year']
        print(ctry)
        Yr = df[df['Code'] == ctry]['Year']
        #print(Yr)
        ST_yr = Yr.iloc[0]
        print(ST_yr)
        l = len(Yr)
        #print(l)
        ED_yr = Yr.iloc[l-1]
        print(ED_yr)
        x = df[df['Code'] == ctry]['GDP per capita, PPP (constant 2017 international $)']
        y = df[df['Code'] == ctry]['Human Development Index']
        print(x)
        print(y)
        s = 2
        lw = 2
        #s = df[df['Code'] == ctry]['Population (historical estimates)']
        #ax.plot3D(x, y, z)
        #ax.set_ylim3d(0, 28)
        
        """
        if clr_code[i] == 'Blue':
            for k in range(ED_yr-ST_yr+1):
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Blues(28+k*6))
        elif clr_code[i] == 'Purp':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Purples(28+k*6))
        elif clr_code[i] == 'Green':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greens(28+k*6))
        elif clr_code[i] == 'Red':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Reds(28+k*6))
        elif clr_code[i] == 'Org':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Oranges(28+k*6))
        elif clr_code[i] == 'Gry':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greys(28+k*6))
        elif clr_code[i] == 'GnBu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.GnBu(28+k*6))
        elif clr_code[i] == 'RdPu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.RdPu(28+k*6))
        elif clr_code[i] == 'PuRd':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuRd(28+k*6))
        elif clr_code[i] == 'PuBu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuBu(28+k*6))
        """


        if clr_code[i] == 'Blue':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Blues(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6, color='steelblue')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='steelblue')
            
        
        elif clr_code[i] == 'Purp':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):  
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])
                kk = k  
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Purples(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='purple')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='purple')
            
        
        elif clr_code[i] == 'Green':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])
                kk = k  
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greens(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='green')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='green')
            
        elif clr_code[i] == 'Red':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Reds(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='red')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='red')
            
        
        elif clr_code[i] == 'Org':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1): 
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Oranges(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='orange')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='orange')
            
        
        elif clr_code[i] == 'Gry':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greys(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color='gray')
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color='gray')
            
        
        elif clr_code[i] == 'GnBu':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.GnBu(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color=cm.GnBu(28+k*6))
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color=cm.GnBu(28+k*6))
            
        
        elif clr_code[i] == 'RdPu':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.RdPu(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color=cm.RdPu(28+k*6))
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color=cm.RdPu(28+k*6))
            
        
        elif clr_code[i] == 'PuRd':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuRd(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color=cm.PuRd(28+k*6))
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color=cm.PuRd(28+k*6))
            
        
        elif clr_code[i] == 'PuBu':
            xx = []; yy = []
            for k in range(ED_yr-ST_yr+1):    
                xx.append(x.iloc[k])
                yy.append(y.iloc[k])  
                kk = k
                #plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuBu(28+k*6))
            plt.plot(xx, yy, linewidth=lw, alpha=0.6,color=cm.PuBu(28+k*6))
            plt.plot(x.iloc[kk], y.iloc[kk], marker='o', markersize=s, color=cm.PuBu(28+k*6))
                    
        




        #input()
        plt.text(x.iloc[k], y.iloc[k], f'{ctry}', **style)
# Out:
# ['DNK']
# DNK
# 1990
# 2021
# 1271    39027.980
# 1272    39469.324
# 1273    40108.890
# 1274    39979.758
# 1275    41969.688
# 1276    43015.676
# 1277    44013.387
# 1278    45260.137
# 1279    46096.370
# 1280    47298.540
# 1281    48907.010
# 1282    49133.223
# 1283    49204.900
# 1284    49262.645
# 1285    50446.543
# 1286    51483.273
# 1287    53322.290
# 1288    53569.027
# 1289    52982.530
# 1290    50114.050
# 1291    50825.414
# 1292    51293.207
# 1293    51216.310
# 1294    51479.266
# 1295    52048.336
# 1296    52892.645
# 1297    54185.008
# 1298    55356.680
# 1299    56178.773
# 1300    56813.965
# 1301    55518.598
# 1302    57962.652
# Name: GDP per capita, PPP (constant 2017 international $), dtype: float64
# 1271    0.834
# 1272    0.838
# 1273    0.841
# 1274    0.844
# 1275    0.851
# 1276    0.854
# 1277    0.862
# 1278    0.869
# 1279    0.876
# 1280    0.886
# 1281    0.889
# 1282    0.895
# 1283    0.896
# 1284    0.901
# 1285    0.906
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

gdp = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/GDP/gdp-per-capita-worldbank.csv')

df = pd.merge(gdp, hdi)
#print(df)
#df = pd.merge(df1, ppl)

#data1 = df[df['Human Development Index'] >= 0.5]
#data2 = data1[data1['Per-capita greenhouse gas emissions in CO₂ equivalents'] <= 5]
#print(data2)
#data = data2.groupby('Entity')[['Human Development Index', 'Per-capita greenhouse gas emissions in CO₂ equivalents']].mean()
#print(data)

#print(df)
#data1 = df[df['Per-capita greenhouse gas emissions in CO₂ equivalents'] > 40]
#data = data1[data1['Per-capita greenhouse gas emissions in CO₂ equivalents'] < 50]
#print(data.head(20))
#plt.plot(df['Year'], df['Per-capita greenhouse gas emissions in CO₂ equivalents'])
#plt.show()

fig = plt.subplot()
plt.title('Human Development Index vs. GDP per capita (1990-2021)', fontsize=10)
plt.xlim(0, 120000)
plt.ylim(0, 1)
plt.xlabel('Per-capita GDP ($)', fontsize=10)
plt.ylabel('Human Development Index', fontsize=10)
#plt.show()

#print(df)
style = dict(size=6, color='k')
for i, catgry in enumerate(ctry_code):
    print(catgry)
    for ctry in catgry:
        #ax = plt.axes(projection='3d')
        #z = df[df['Code'] == 'USA']['Year']
        print(ctry)
        Yr = df[df['Code'] == ctry]['Year']
        #print(Yr)
        ST_yr = Yr.iloc[0]
        print(ST_yr)
        l = len(Yr)
        #print(l)
        ED_yr = Yr.iloc[l-1]
        print(ED_yr)
        x = df[df['Code'] == ctry]['GDP per capita, PPP (constant 2017 international $)']
        y = df[df['Code'] == ctry]['Human Development Index']
        print(x)
        print(y)
        #s = df[df['Code'] == ctry]['Population (historical estimates)']
        #ax.plot3D(x, y, z)
        #ax.set_ylim3d(0, 28)

        if clr_code[i] == 'Blue':
            for k in range(ED_yr-ST_yr+1):
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Blues(28+k*6))
        elif clr_code[i] == 'Purp':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Purples(28+k*6))
        elif clr_code[i] == 'Green':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greens(28+k*6))
        elif clr_code[i] == 'Red':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Reds(28+k*6))
        elif clr_code[i] == 'Org':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Oranges(28+k*6))
        elif clr_code[i] == 'Gry':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greys(28+k*6))
        elif clr_code[i] == 'GnBu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.GnBu(28+k*6))
        elif clr_code[i] == 'RdPu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.RdPu(28+k*6))
        elif clr_code[i] == 'PuRd':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuRd(28+k*6))
        elif clr_code[i] == 'PuBu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuBu(28+k*6))
                
        #input()
        plt.text(x.iloc[k], y.iloc[k], f'{ctry}', **style)
# Out:
# ['DNK']
# DNK
# 1990
# 2021
# 1271    39027.980
# 1272    39469.324
# 1273    40108.890
# 1274    39979.758
# 1275    41969.688
# 1276    43015.676
# 1277    44013.387
# 1278    45260.137
# 1279    46096.370
# 1280    47298.540
# 1281    48907.010
# 1282    49133.223
# 1283    49204.900
# 1284    49262.645
# 1285    50446.543
# 1286    51483.273
# 1287    53322.290
# 1288    53569.027
# 1289    52982.530
# 1290    50114.050
# 1291    50825.414
# 1292    51293.207
# 1293    51216.310
# 1294    51479.266
# 1295    52048.336
# 1296    52892.645
# 1297    54185.008
# 1298    55356.680
# 1299    56178.773
# 1300    56813.965
# 1301    55518.598
# 1302    57962.652
# Name: GDP per capita, PPP (constant 2017 international $), dtype: float64
# 1271    0.834
# 1272    0.838
# 1273    0.841
# 1274    0.844
# 1275    0.851
# 1276    0.854
# 1277    0.862
# 1278    0.869
# 1279    0.876
# 1280    0.886
# 1281    0.889
# 1282    0.895
# 1283    0.896
# 1284    0.901
# 1285    0.906
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

gdp = pd.read_csv('/Users/kurozuhajime/Desktop/SDGs/GDP/gdp-per-capita-worldbank.csv')

df = pd.merge(gdp, ghg)
#print(df)
#df = pd.merge(df1, ppl)

#data1 = df[df['Human Development Index'] >= 0.5]
#data2 = data1[data1['Per-capita greenhouse gas emissions in CO₂ equivalents'] <= 5]
#print(data2)
#data = data2.groupby('Entity')[['Human Development Index', 'Per-capita greenhouse gas emissions in CO₂ equivalents']].mean()
#print(data)

#print(df)
#data1 = df[df['Per-capita greenhouse gas emissions in CO₂ equivalents'] > 40]
#data = data1[data1['Per-capita greenhouse gas emissions in CO₂ equivalents'] < 50]
#print(data.head(20))
#plt.plot(df['Year'], df['Per-capita greenhouse gas emissions in CO₂ equivalents'])
#plt.show()

fig = plt.subplot()
plt.title('GDP per capita vs. Per-capita GHG emissions (1990-2021)', fontsize=10)
plt.ylim(0, 120000)
plt.xlim(0, 120)
plt.ylabel('Per-capita GDP ($)', fontsize=10)
plt.xlabel('Per-capita GHG emissions (t CO2eq)', fontsize=10)
#plt.show()

#print(df)
style = dict(size=6, color='k')
for i, catgry in enumerate(ctry_code):
    print(catgry)
    for ctry in catgry:
        #ax = plt.axes(projection='3d')
        #z = df[df['Code'] == 'USA']['Year']
        print(ctry)
        Yr = df[df['Code'] == ctry]['Year']
        #print(Yr)
        ST_yr = Yr.iloc[0]
        #print(ST_yr)
        l = len(Yr)
        #print(l)
        ED_yr = Yr.iloc[l-1]
        #print(ED_yr)
        x = df[df['Code'] == ctry]['Per-capita greenhouse gas emissions in CO₂ equivalents']
        y = df[df['Code'] == ctry]['GDP per capita, PPP (constant 2017 international $)']
        #print(x)
        #print(y)
        #s = df[df['Code'] == ctry]['Population (historical estimates)']
        #ax.plot3D(x, y, z)
        #ax.set_ylim3d(0, 28)

        if clr_code[i] == 'Blue':
            for k in range(ED_yr-ST_yr+1):
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Blues(28+k*6))
        elif clr_code[i] == 'Purp':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Purples(28+k*6))
        elif clr_code[i] == 'Green':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greens(28+k*6))
        elif clr_code[i] == 'Red':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Reds(28+k*6))
        elif clr_code[i] == 'Org':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Oranges(28+k*6))
        elif clr_code[i] == 'Gry':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.Greys(28+k*6))
        elif clr_code[i] == 'GnBu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.GnBu(28+k*6))
        elif clr_code[i] == 'RdPu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.RdPu(28+k*6))
        elif clr_code[i] == 'PuRd':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuRd(28+k*6))
        elif clr_code[i] == 'PuBu':
            for k in range(ED_yr-ST_yr+1):    
                plt.plot(x.iloc[k], y.iloc[k], marker='o', markersize=2, color=cm.PuBu(28+k*6))
                
        #input()
        plt.text(x.iloc[k], y.iloc[k], f'{ctry}', **style)
# Out:
# ['DNK']
# DNK
# ['USA', 'CAN']
# USA
# CAN
# ['FRA', 'GBR']
# FRA
# GBR
# ['QAT', 'ARE']
# QAT
# ARE
# ['CRI', 'BRA', 'CHL']
# CRI
# BRA
# CHL
# ['AUS', 'NZL']
# AUS
# NZL
# ['ETH', 'TZA', 'TCD']
# ETH
# TZA
# TCD
# ['MYS', 'JPN']
# MYS
# JPN
# ['IND', 'LKA']
# IND
# LKA
# ['UZB', 'AFG']
# UZB
# AFG
